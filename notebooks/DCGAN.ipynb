# %% [markdown]
# # Introduction a Deep Convolutional Generative Adversarial Network (DCGAN)

# %% [markdown]
# ### Étape 1 - Importation des bibliothèques

# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for assembling a Neural Network model
from keras.layers import Dense, Reshape, Flatten, Conv2D, Conv2DTranspose, ReLU, LeakyReLU, Dropout # adding layers to the Neural Network model
from tensorflow.keras.utils import plot_model # for plotting model diagram
from tensorflow.keras.optimizers import Adam # for model optimization 


# Data manipulation
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for scaling inputs used in the generator and discriminator


# Visualization
import cv2 # for ingesting images
print('OpenCV: %s' % cv2.__version__) # print version
import matplotlib 
import matplotlib.pyplot as plt # or data visualizationa
print('matplotlib: %s' % matplotlib.__version__) # print version
import graphviz # for showing model diagram
print('graphviz: %s' % graphviz.__version__) # print version


# Other utilities
import sys
import os

# Assign main directory to a variable
main_dir=os.path.dirname(sys.path[0])
print(main_dir)
# Out:
# Tensorflow/Keras: 2.9.0
# numpy: 1.23.0
# sklearn: 1.1.1
# OpenCV: 4.6.0
# matplotlib: 3.5.2
# graphviz: 0.20.1
# /home/bahri-khalid/Projects/3D_VAE_GAN

# %% [markdown]
# ### Étape 2 - Chargement et traitement du jeu de données d'images Caltech101
# - Source and Licence: http://www.vision.caltech.edu/Image_Datasets/Caltech101/

# %%
ImgLocation=main_dir+"/resources/data/caltech-101/101_ObjectCategories/"

# List image categories we are interested in (We will only use "Faces_easy" this time)
CATEGORIES = set(["Faces_easy"])

# Create a list to store image paths
ImagePaths=[]
for category in CATEGORIES:
    for image in list(os.listdir(ImgLocation+category)):
        ImagePaths=ImagePaths+[ImgLocation+category+"/"+image]
        
# Load images and resize to 64 x 64
data_lowres=[]
for img in ImagePaths:
    image = cv2.imread(img)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_lowres = cv2.resize(image, (64, 64))
    data_lowres.append(image_lowres)
    
# Convert image data to numpy array and standardize values (divide by 255 since RGB values ranges from 0 to 255)
data_lowres = np.array(data_lowres, dtype="float") / 255.0

# Show data shape
print("Shape of data_lowres: ", data_lowres.shape)
# Out:
# Shape of data_lowres:  (435, 64, 64, 3)

# %% [markdown]
# ##### Display a few real images (64 x 64 pixels)

# %%
# Display 10 real images
fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(16,9), facecolor='white')
n=0
for i in range(0,2):
    for j in range(0,5):
        axs[i,j].matshow(data_lowres[n])
        n=n+1
plt.show()

# %%
# Scaler
scaler=MinMaxScaler(feature_range=(-1, 1))

# Select images that we want to use fro model trainng
data=data_lowres.copy()
print("Original shape of the data: ", data.shape)

# Reshape array
data=data.reshape(-1, 1)
print("Reshaped data: ", data.shape)

# Fit the scaler
scaler.fit(data)

# Scale the array
data=scaler.transform(data)

# Reshape back to the original shape
data=data.reshape(data_lowres.shape[0], 64, 64, 3)
print("Shape of the scaled array: ", data.shape)
# Out:
# Original shape of the data:  (435, 64, 64, 3)
# Reshaped data:  (5345280, 1)
# Shape of the scaled array:  (435, 64, 64, 3)

# %% [markdown]
# ### Step 3 - Setup GAN

# %% [markdown]
# #### Define Generator model

# %%
def generator(latent_dim):
    model = Sequential(name="Generator") # Model
    
    # Hidden Layer 1: Start with 8 x 8 image
    n_nodes = 8 * 8 * 128 # number of nodes in the first hidden layer
    model.add(Dense(n_nodes, input_dim=latent_dim, name='Generator-Hidden-Layer-1'))
    model.add(Reshape((8, 8, 128), name='Generator-Hidden-Layer-Reshape-1'))
    
    # Hidden Layer 2: Upsample to 16 x 16
    model.add(Conv2DTranspose(filters=128, kernel_size=(4,4), strides=(2,2), padding='same', name='Generator-Hidden-Layer-2'))
    model.add(ReLU(name='Generator-Hidden-Layer-Activation-2'))
                              
    # Hidden Layer 3: Upsample to 32 x 32
    model.add(Conv2DTranspose(filters=256, kernel_size=(4,4), strides=(2,2), padding='same', name='Generator-Hidden-Layer-3'))
    model.add(ReLU(name='Generator-Hidden-Layer-Activation-3'))
    
    # Hidden Layer 4: Upsample to 64 x 64
    model.add(Conv2DTranspose(filters=512, kernel_size=(4,4), strides=(2,2), padding='same', name='Generator-Hidden-Layer-4'))
    model.add(ReLU(name='Generator-Hidden-Layer-Activation-4'))
    
    # Output Layer (Note, we use 3 filters because we have 3 channels for a color image. Grayscale would have only 1 channel)
    model.add(Conv2D(filters=3, kernel_size=(5,5), activation='tanh', padding='same', name='Generator-Output-Layer'))
    return model

# Instantiate
latent_dim=100 # Our latent space has 100 dimensions. We can change it to any number
gen_model = generator(latent_dim)

# Show model summary and plot model diagram
gen_model.summary()
plot_model(gen_model, show_shapes=True, show_layer_names=True, dpi=400) #, to_file='generator_structure.png')
# Out:
# Model: "Generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Generator-Hidden-Layer-1 (D  (None, 8192)             827392
#  ense)
#
#  Generator-Hidden-Layer-Resh  (None, 8, 8, 128)        0
#  ape-1 (Reshape)
#
#  Generator-Hidden-Layer-2 (C  (None, 16, 16, 128)      262272
#  onv2DTranspose)
#
#  Generator-Hidden-Layer-Acti  (None, 16, 16, 128)      0
#  vation-2 (ReLU)
#
#  Generator-Hidden-Layer-3 (C  (None, 32, 32, 256)      524544
#  onv2DTranspose)
#
#  Generator-Hidden-Layer-Acti  (None, 32, 32, 256)      0
#  vation-3 (ReLU)
#
#  Generator-Hidden-Layer-4 (C  (None, 64, 64, 512)      2097664
#  onv2DTranspose)
#
#  Generator-Hidden-Layer-Acti  (None, 64, 64, 512)      0
#  vation-4 (ReLU)
#
#  Generator-Output-Layer (Con  (None, 64, 64, 3)        38403
#  v2D)
#
# =================================================================
# Total params: 3,750,275
# Trainable params: 3,750,275
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# #### Define a Discriminator model

# %%
def discriminator(in_shape=(64,64,3)):
    model = Sequential(name="Discriminator") # Model
    
    # Hidden Layer 1
    model.add(Conv2D(filters=64, kernel_size=(4,4), strides=(2, 2), padding='same', input_shape=in_shape, name='Discriminator-Hidden-Layer-1'))
    model.add(LeakyReLU(alpha=0.2, name='Discriminator-Hidden-Layer-Activation-1'))
    
    # Hidden Layer 2
    model.add(Conv2D(filters=128, kernel_size=(4,4), strides=(2, 2), padding='same', input_shape=in_shape, name='Discriminator-Hidden-Layer-2'))
    model.add(LeakyReLU(alpha=0.2, name='Discriminator-Hidden-Layer-Activation-2'))
    
    # Hidden Layer 3
    model.add(Conv2D(filters=128, kernel_size=(4,4), strides=(2, 2), padding='same', input_shape=in_shape, name='Discriminator-Hidden-Layer-3'))
    model.add(LeakyReLU(alpha=0.2, name='Discriminator-Hidden-Layer-Activation-3'))
    
    # Flatten and Output Layers
    model.add(Flatten(name='Discriminator-Flatten-Layer')) # Flatten the shape
    model.add(Dropout(0.3, name='Discriminator-Flatten-Layer-Dropout')) # Randomly drop some connections for better generalization
    model.add(Dense(1, activation='sigmoid', name='Discriminator-Output-Layer')) # Output Layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5), metrics=['accuracy'])
    return model

# Instantiate
dis_model = discriminator()

# Show model summary and plot model diagram
dis_model.summary()
plot_model(dis_model, show_shapes=True, show_layer_names=True, dpi=400) #, to_file='discriminator_structure.png')
# Out:
# Model: "Discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Discriminator-Hidden-Layer-  (None, 32, 32, 64)       3136
#  1 (Conv2D)
#
#  Discriminator-Hidden-Layer-  (None, 32, 32, 64)       0
#  Activation-1 (LeakyReLU)
#
#  Discriminator-Hidden-Layer-  (None, 16, 16, 128)      131200
#  2 (Conv2D)
#
#  Discriminator-Hidden-Layer-  (None, 16, 16, 128)      0
#  Activation-2 (LeakyReLU)
#
#  Discriminator-Hidden-Layer-  (None, 8, 8, 128)        262272
#  3 (Conv2D)
#
#  Discriminator-Hidden-Layer-  (None, 8, 8, 128)        0
#  Activation-3 (LeakyReLU)
#
#  Discriminator-Flatten-Layer  (None, 8192)             0
#   (Flatten)
#
#  Discriminator-Flatten-Layer  (None, 8192)             0
#  -Dropout (Dropout)
#
#  Discriminator-Output-Layer   (None, 1)                8193
#  (Dense)
#
# =================================================================
# Total params: 404,801
# Trainable params: 404,801
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# #### Combine Generator and Discriminator models into trainable GAN

# %%
def def_gan(generator, discriminator):
    
    # We don't want to train the weights of discriminator at this stage. Hence, make it not trainable
    discriminator.trainable = False
    
    # Combine
    model = Sequential(name="DCGAN") # GAN Model
    model.add(generator) # Add Generator
    model.add(discriminator) # Add Disriminator
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002))
    return model

# Instantiate
gan_model = def_gan(gen_model, dis_model)

# Show model summary and plot model diagram
gan_model.summary()
plot_model(gan_model, show_shapes=True, show_layer_names=True, dpi=400) #, to_file='dcgan_structure.png')
# Out:
# Model: "DCGAN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Generator (Sequential)      (None, 64, 64, 3)         3750275
#
#  Discriminator (Sequential)  (None, 1)                 404801
#
# =================================================================
# Total params: 4,155,076
# Trainable params: 3,750,275
# Non-trainable params: 404,801
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ### Step 4 - Setup functions to:
# - sample the latent space
# - sample real images
# - generate fake images with the generator model

# %% [markdown]
# ##### Set up a function to sample real images

# %%
def real_samples(n, dataset):
    
    # Samples of real data
    X = dataset[np.random.choice(dataset.shape[0], n, replace=True), :]

    # Class labels
    y = np.ones((n, 1))

    return X, y

# %% [markdown]
# ##### Generate points in the latent space, which we will use as inputs for the generator

# %%
def latent_vector(latent_dim, n):
    
    # Generate points in the latent space
    latent_input = np.random.randn(latent_dim * n)
    
    # Reshape into a batch of inputs for the network
    latent_input = latent_input.reshape(n, latent_dim)
    return latent_input

# %% [markdown]
# ##### The below function will use the generator to generate n fake examples together with class labels

# %%
def fake_samples(generator, latent_dim, n):
    
    # Generate points in latent space
    latent_output = latent_vector(latent_dim, n)
    
    # Predict outputs (i.e., generate fake samples)
    X = generator.predict(latent_output)
    
    # Create class labels
    y = np.zeros((n, 1))
    return X, y

# %% [markdown]
# ### Step 5 - Setup functions for model performance evaluation and training

# %% [markdown]
# ##### Show Discriminator model accuracy and plot real vs. fake (generated) comparison

# %%
def performance_summary(generator, discriminator, dataset, latent_dim, n=50):
    
    # Get samples of the real data
    x_real, y_real = real_samples(n, dataset)
    # Evaluate the descriminator on real data
    _, real_accuracy = discriminator.evaluate(x_real, y_real, verbose=0)
    
    # Get fake (generated) samples
    x_fake, y_fake = fake_samples(generator, latent_dim, n)
    # Evaluate the descriminator on fake (generated) data
    _, fake_accuracy = discriminator.evaluate(x_fake, y_fake, verbose=0)
    
    # summarize discriminator performance
    print("*** Evaluation ***")
    print("Discriminator Accuracy on REAL images: ", real_accuracy)
    print("Discriminator Accuracy on FAKE (generated) images: ", fake_accuracy)
    
    # Create a 2D scatter plot to show real and fake (generated) data points
    # Display 6 fake images
    x_fake_inv_trans=x_fake.reshape(-1, 1)
    x_fake_inv_trans=scaler.inverse_transform(x_fake_inv_trans)
    x_fake_inv_trans=x_fake_inv_trans.reshape(n, 64, 64, 3)
    
    fig, axs = plt.subplots(2, 3, sharey=False, tight_layout=True, figsize=(12,6), facecolor='white')
    k=0
    for i in range(0,2):
        for j in range(0,3):
            axs[i,j].matshow(x_fake_inv_trans[k])
            k=k+1
    plt.show()

# %% [markdown]
# ### Définir une fonction pour entraîner notre modèle DCGAN (générateur et discriminateur)

# %%
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=1001, n_batch=32, n_eval=100):
    
    # Our batch to train the discriminator will consist of half real images and half fake (generated) images
    half_batch = int(n_batch / 2)
    
    # We will manually enumare epochs 
    for i in range(n_epochs):
    
    # Discriminator training
        # Prep real samples
        x_real, y_real = real_samples(half_batch, dataset)
        # Prep fake (generated) samples
        x_fake, y_fake = fake_samples(g_model, latent_dim, half_batch)
        
        # Train the discriminator using real and fake samples
        X, y = np.vstack((x_real, x_fake)), np.vstack((y_real, y_fake))
        discriminator_loss, _ = d_model.train_on_batch(X, y)
    
    # Generator training
        # Get values from the latent space to be used as inputs for the generator
        x_gan = latent_vector(latent_dim, n_batch)
        # While we are generating fake samples, 
        # we want GAN generator model to create examples that resemble the real ones,
        # hence we want to pass labels corresponding to real samples, i.e. y=1, not 0.
        y_gan = np.ones((n_batch, 1))
        
        # Train the generator via a composite GAN model
        generator_loss = gan_model.train_on_batch(x_gan, y_gan)
        
        # Evaluate the model at every n_eval epochs
        if (i) % n_eval == 0:
            print("Epoch number: ", i)
            print("*** Training ***")
            print("Discriminator Loss ", discriminator_loss)
            print("Generator Loss: ", generator_loss)
            performance_summary(g_model, d_model, dataset, latent_dim)

# %% [markdown]
# ### Step 6 - Train the model and plot the results

# %% [markdown]
# ##### Use the above train function to train our GAN model

# %%
# Train DCGAN model
# 1k epochs
train(gen_model, dis_model, gan_model, data, latent_dim)
# Out:
# 1/1 [==============================] - 1s 901ms/step
# Epoch number:  0
# *** Training ***
# Discriminator Loss  0.6909340620040894
# Generator Loss:  0.6927340030670166
# 2/2 [==============================] - 2s 775ms/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  1.0
# Discriminator Accuracy on FAKE (generated) images:  0.0
# 1/1 [==============================] - 1s 680ms/step
# 1/1 [==============================] - 1s 685ms/step
# 1/1 [==============================] - 1s 728ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 767ms/step
# 1/1 [==============================] - 1s 917ms/step
# 1/1 [==============================] - 1s 821ms/step
# 1/1 [==============================] - 1s 874ms/step
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 1s 909ms/step
# 1/1 [==============================] - 1s 788ms/step
# 1/1 [==============================] - 1s 812ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 801ms/step
# 1/1 [==============================] - 1s 807ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 802ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 793ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 802ms/step
# 1/1 [==============================] - 1s 796ms/step
# 1/1 [==============================] - 1s 792ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 797ms/step
# 1/1 [==============================] - 1s 908ms/step
# 1/1 [==============================] - 1s 801ms/step
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 786ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 789ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 798ms/step
# 1/1 [==============================] - 1s 801ms/step
# 1/1 [==============================] - 1s 800ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 900ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 1s 771ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 1s 778ms/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 767ms/step
# 1/1 [==============================] - 1s 782ms/step
# 1/1 [==============================] - 1s 799ms/step
# 1/1 [==============================] - 1s 780ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 774ms/step
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 1s 767ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 1s 780ms/step
# 1/1 [==============================] - 1s 804ms/step
# 1/1 [==============================] - 1s 809ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 1s 752ms/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 756ms/step
# Epoch number:  100
# *** Training ***
# Discriminator Loss  0.09216748178005219
# Generator Loss:  3.0586318969726562
# 2/2 [==============================] - 2s 857ms/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.9800000190734863
# Discriminator Accuracy on FAKE (generated) images:  1.0
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 778ms/step
# 1/1 [==============================] - 1s 800ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 760ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 771ms/step
# 1/1 [==============================] - 1s 771ms/step
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 771ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 760ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 782ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 766ms/step
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 1s 849ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 804ms/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 823ms/step
# 1/1 [==============================] - 1s 822ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 874ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 985ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 852ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 930ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 903ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 902ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 885ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 885ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 865ms/step
# Epoch number:  200
# *** Training ***
# Discriminator Loss  0.7238999605178833
# Generator Loss:  1.8950108289718628
# 2/2 [==============================] - 3s 1s/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.699999988079071
# Discriminator Accuracy on FAKE (generated) images:  0.7799999713897705
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 849ms/step
# 1/1 [==============================] - 1s 886ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 885ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 937ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 900ms/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 916ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 917ms/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 884ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 886ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 965ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 908ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 881ms/step
# 1/1 [==============================] - 1s 995ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 868ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 881ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 953ms/step
# Epoch number:  300
# *** Training ***
# Discriminator Loss  0.5730036497116089
# Generator Loss:  1.2288634777069092
# 2/2 [==============================] - 3s 1s/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.6800000071525574
# Discriminator Accuracy on FAKE (generated) images:  1.0
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 885ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 927ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 886ms/step
# 1/1 [==============================] - 1s 852ms/step
# 1/1 [==============================] - 1s 902ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 884ms/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 890ms/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 1s 995ms/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 881ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 884ms/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 868ms/step
# 1/1 [==============================] - 1s 877ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 912ms/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 902ms/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 906ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 912ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 909ms/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 952ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 874ms/step
# Epoch number:  400
# *** Training ***
# Discriminator Loss  0.7285133600234985
# Generator Loss:  0.9295879006385803
# 2/2 [==============================] - 3s 987ms/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.7200000286102295
# Discriminator Accuracy on FAKE (generated) images:  0.5400000214576721
# 1/1 [==============================] - 1s 822ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 1s 905ms/step
# 1/1 [==============================] - 1s 906ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 884ms/step
# 1/1 [==============================] - 1s 874ms/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 881ms/step
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 868ms/step
# 1/1 [==============================] - 1s 852ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 946ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 897ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 849ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 809ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 790ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 1s 794ms/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 778ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 781ms/step
# 1/1 [==============================] - 1s 781ms/step
# 1/1 [==============================] - 1s 780ms/step
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 773ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 774ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 777ms/step
# 1/1 [==============================] - 1s 908ms/step
# 1/1 [==============================] - 1s 804ms/step
# 1/1 [==============================] - 1s 817ms/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 773ms/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 907ms/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 903ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 813ms/step
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 825ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 832ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 879ms/step
# Epoch number:  500
# *** Training ***
# Discriminator Loss  0.7078127264976501
# Generator Loss:  0.8697845935821533
# 2/2 [==============================] - 3s 1s/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.46000000834465027
# Discriminator Accuracy on FAKE (generated) images:  0.6800000071525574
# 1/1 [==============================] - 1s 905ms/step
# 1/1 [==============================] - 1s 800ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 1s 817ms/step
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 825ms/step
# 1/1 [==============================] - 1s 821ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 815ms/step
# 1/1 [==============================] - 1s 796ms/step
# 1/1 [==============================] - 1s 881ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 771ms/step
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 1s 731ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 740ms/step
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 800ms/step
# 1/1 [==============================] - 1s 781ms/step
# 1/1 [==============================] - 1s 810ms/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 1s 767ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 1s 886ms/step
# 1/1 [==============================] - 1s 732ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 1s 726ms/step
# 1/1 [==============================] - 1s 823ms/step
# 1/1 [==============================] - 1s 789ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 777ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 874ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 913ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 905ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 1000ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 812ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 824ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 909ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 837ms/step
# Epoch number:  600
# *** Training ***
# Discriminator Loss  0.6249676942825317
# Generator Loss:  0.7708896994590759
# 2/2 [==============================] - 3s 978ms/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.8600000143051147
# Discriminator Accuracy on FAKE (generated) images:  0.5
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 819ms/step
# 1/1 [==============================] - 1s 842ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 821ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 817ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 824ms/step
# 1/1 [==============================] - 1s 812ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 908ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 824ms/step
# 1/1 [==============================] - 1s 823ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 833ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 832ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 812ms/step
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 842ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 816ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 833ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 852ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 832ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 803ms/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 913ms/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 824ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 833ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 816ms/step
# 1/1 [==============================] - 1s 853ms/step
# 1/1 [==============================] - 1s 825ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Epoch number:  700
# *** Training ***
# Discriminator Loss  0.6905605792999268
# Generator Loss:  0.7744598388671875
# 2/2 [==============================] - 3s 1s/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.699999988079071
# Discriminator Accuracy on FAKE (generated) images:  0.699999988079071
# 1/1 [==============================] - 1s 897ms/step
# 1/1 [==============================] - 1s 933ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 933ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 937ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 814ms/step
# 1/1 [==============================] - 1s 832ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 831ms/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 809ms/step
# 1/1 [==============================] - 1s 813ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 833ms/step
# 1/1 [==============================] - 1s 928ms/step
# 1/1 [==============================] - 1s 849ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 1000ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 941ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 1s 927ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 941ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 923ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 930ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 1s 923ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 931ms/step
# Epoch number:  800
# *** Training ***
# Discriminator Loss  0.6308308839797974
# Generator Loss:  0.8257172703742981
# 2/2 [==============================] - 3s 1s/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.7599999904632568
# Discriminator Accuracy on FAKE (generated) images:  0.8600000143051147
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 930ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 933ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 993ms/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 996ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 999ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 941ms/step
# 1/1 [==============================] - 1s 937ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 996ms/step
# 1/1 [==============================] - 1s 927ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 941ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 933ms/step
# 1/1 [==============================] - 1s 977ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 937ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Epoch number:  900
# *** Training ***
# Discriminator Loss  0.6560707092285156
# Generator Loss:  0.8202775716781616
# 2/2 [==============================] - 3s 1s/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.6200000047683716
# Discriminator Accuracy on FAKE (generated) images:  0.8999999761581421
# 1/1 [==============================] - 1s 913ms/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 941ms/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 1s 923ms/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 923ms/step
# 1/1 [==============================] - 1s 912ms/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 919ms/step
# 1/1 [==============================] - 1s 825ms/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 807ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 825ms/step
# 1/1 [==============================] - 1s 821ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 819ms/step
# 1/1 [==============================] - 1s 806ms/step
# 1/1 [==============================] - 1s 825ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 816ms/step
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 1s 900ms/step
# 1/1 [==============================] - 1s 894ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 833ms/step
# 1/1 [==============================] - 1s 917ms/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 802ms/step
# 1/1 [==============================] - 1s 792ms/step
# 1/1 [==============================] - 1s 832ms/step
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 767ms/step
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 792ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 1s 841ms/step
# 1/1 [==============================] - 1s 852ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 818ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 822ms/step
# 1/1 [==============================] - 1s 842ms/step
# 1/1 [==============================] - 1s 808ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 833ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 803ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 833ms/step
# 1/1 [==============================] - 1s 835ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 813ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 828ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 817ms/step
# 1/1 [==============================] - 1s 822ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 849ms/step
# 1/1 [==============================] - 1s 840ms/step
# Epoch number:  1000
# *** Training ***
# Discriminator Loss  0.6268478631973267
# Generator Loss:  0.9110121726989746
# 2/2 [==============================] - 3s 945ms/step
# *** Evaluation ***
# Discriminator Accuracy on REAL images:  0.5600000023841858
# Discriminator Accuracy on FAKE (generated) images:  0.8799999952316284

# %%
# Continue training DCGAN model for another 1000 epochs (Total: 2K epochs)
train(gen_model, dis_model, gan_model, data, latent_dim)

# %%
# Save the current versions of the models (After 2k epcohs)
gen_model.save(main_dir+"/data/models/007a_Generator_2k.h5")
dis_model.save(main_dir+"/data/models/007a_Discriminator_2k.h5")
gan_model.save(main_dir+"/data/models/007a_GAN_2k.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Continue training DCGAN model for another 1000 epochs (Total: 3K epochs)
train(gen_model, dis_model, gan_model, data, latent_dim)

# %%
# Save the current versions of the models (After 3k epcohs)
gen_model.save(main_dir+"/data/models/007b_Generator_3k.h5")
dis_model.save(main_dir+"/data/models/007b_Discriminator_3k.h5")
gan_model.save(main_dir+"/data/models/007b_GAN_3k.h5")

# %% [markdown]
# ##### Example how to load a previously saved model

# %%
# Add library
# from keras.models import load_model
# Load saved models
# gen_model = load_model(main_dir+"/data/models/007b_Generator_3k.h5")
# dis_model = load_model(main_dir+"/data/models/007b_Discriminator_3k.h5")
# gan_model = load_model(main_dir+"/data/models/007b_GAN_3k.h5")

# %% [markdown]
# ---

# %% [markdown]
# ### Step 7 - Evaluate model performace and use the Generator to create a bunch of images

# %%
def performance_eval(epoch, generator, discriminator, dataset, latent_dim, n=40):
    
    # Get samples of the real data
    x_real, y_real = real_samples(n, dataset)
    # Evaluate the descriminator on real data
    _, real_accuracy = discriminator.evaluate(x_real, y_real, verbose=0)
    
    # Get fake (generated) samples
    x_fake, y_fake = fake_samples(generator, latent_dim, n)
    # Evaluate the descriminator on fake (generated) data
    _, fake_accuracy = discriminator.evaluate(x_fake, y_fake, verbose=0)
    
    # summarize discriminator performance
    print("Epoch number: ", epoch)
    print("Discriminator Accuracy on REAL images: ", real_accuracy)
    print("Discriminator Accuracy on FAKE (generated) images: ", fake_accuracy)
    
    # Create a 2D scatter plot to show real and fake (generated) data points
    # Display 20 fake images
    # Display 6 fake images
    x_fake_inv_trans=x_fake.reshape(-1, 1)
    x_fake_inv_trans=scaler.inverse_transform(x_fake_inv_trans)
    x_fake_inv_trans=x_fake_inv_trans.reshape(n, 64, 64, 3)
    
    fig, axs = plt.subplots(8, 5, sharey=False, tight_layout=True, figsize=(48,48), facecolor='white')
    k=0
    for i in range(0,8):
        for j in range(0,5):
            axs[i,j].matshow(x_fake_inv_trans[k])
            k=k+1
    plt.show()

# %%
# After 2K epochs
performance_eval(0, gen_model, dis_model, data, 100)

# %%
# After 3K epochs
performance_eval(0, gen_model, dis_model, data, 100)

# %% [markdown]
# ---

# %% [markdown]
# ### Appendix - Generate one random Image

# %%
# Generate an image of a bonsai tree using random latent vector
x_fake, y_fake = fake_samples(gen_model, 100, 1)

# Shape and inverse transpose the generated image
x_fake_inv_trans=x_fake.reshape(-1, 1)
x_fake_inv_trans=scaler.inverse_transform(x_fake_inv_trans)
x_fake_inv_trans=x_fake_inv_trans.reshape(64, 64, 3)

# %%
# Show the generated image
fig, ax = plt.subplots(figsize=(16,9), dpi=20)
ax.matshow(x_fake_inv_trans)
plt.axis('off')
plt.show()

# %% [markdown]
# # End of Program
