# %%
data_path = '../volumetric_data/chair/30/train/'

# %%
import scipy.io
import numpy as np

# %%
mesh_path = data_path+'chair_000000182_2.mat'
mat = scipy.io.loadmat(mesh_path)

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'instance'])

# %%
mat['instance'].shape
# Out:
# (30, 30, 30)

# %%
type(mat['instance'])
# Out:
# numpy.ndarray

# %%
data = mat['instance']

# %%
# np.save('test.npy', data, allow_pickle=True, fix_imports=True)

# %%
alpha = 0.5
linewidth = 0.8
axisoff=False,
def visualizeVxl(voxels):
    ax = plt.figure(figsize=(50,50)).add_subplot(projection='3d')
    ax.voxels(voxels, facecolors='crimson', edgecolor='k')
    if axisoff:
        ax.set_axis_off()
    plt.show()

# %%
def GetVox(mesh_path):
    mat = scipy.io.loadmat(mesh_path)
    vox = mat['instance']
    return vox

# %%
mesh_path = data_path+'chair_000000182_3.mat'
vox = GetVox(mesh_path)
visualizeVxl(vox)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv3D, MaxPooling3D
from tensorflow.keras.utils import to_categorical
import h5py
import numpy as np
import matplotlib.pyplot as plt
class Generator:
    def __init__(self,args):
        
        self.layer1 = tf.keras.layers.Conv3D(
            filters,
            kernel_size = (4,4,4),
            strides=(1, 1, 1)
            )
        self.model = Sequential()
        model.add(Conv3D(32, kernel_size=(4, 4, 4),strides=(1, 1, 1), activation='relu', input_shape=sample_shape))
        model.add(Conv3D(64, kernel_size=(4, 4, 4),strides=(2, 2, 2), activation='relu')
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Flatten())
        model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(no_classes, activation='softmax'))
